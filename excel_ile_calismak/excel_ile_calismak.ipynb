# %%
from IPython.display import Image

# %%
Image(filename = "sheet1.jpg")

# %%
Image(filename = "sheet2.jpg")

# %%
import pandas as pd

# %%
#conda install xlrd
#conda install openpyxl

#hata verirse çalıştırın

# !conda install xlrd
# !conda install openpyxl

# %%
df = pd.read_excel("excel_dosyasi.xlsx")
df
# Out:
#    A1  B1  C1  D1
# 0   2   2   2   2
# 1   3   3   3   3
# 2   4   4   4   4
# 3   5   5   5   5

# %%
#sheet belirtelim

df = pd.read_excel("excel_dosyasi.xlsx",
                  sheet_name = 1)

#sheet 1 için sheet_name = 0
#sheet 2 için sheet_name = 1

df
# Out:
#    A2  B2  C2  D2
# 0   2   2   2   2
# 1   3   3   3   3
# 2   4   4   4   4
# 3   5   5   5   5

# %%
#veya direkt ismini yazalım
df = pd.read_excel("excel_dosyasi.xlsx",
                sheet_name="Sheet2")

df
# Out:
#    A2  B2  C2  D2
# 0   2   2   2   2
# 1   3   3   3   3
# 2   4   4   4   4
# 3   5   5   5   5

# %%
#iki sayfa birden import etme
df = pd.read_excel("excel_dosyasi.xlsx",
                sheet_name = ["Sheet1", "Sheet2"])

df
# Out:
# {'Sheet1':    A1  B1  C1  D1
#  0   2   2   2   2
#  1   3   3   3   3
#  2   4   4   4   4
#  3   5   5   5   5,
#  'Sheet2':    A2  B2  C2  D2
#  0   2   2   2   2
#  1   3   3   3   3
#  2   4   4   4   4
#  3   5   5   5   5}

# %%
#indeksleme yapabilirsiniz

df["Sheet2"]
# Out:
#    A2  B2  C2  D2
# 0   2   2   2   2
# 1   3   3   3   3
# 2   4   4   4   4
# 3   5   5   5   5
