# %%
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

# %%
import pandas as pd
titanic = pd.read_csv(url)

# %%
(titanic            #veri
.isnull()           #eksik veriler
.sum()              #eksik verileri topla
/titanic.isnull()   #yüzde için
.count()            #eksikleri say
#büyükten küçüğe sırala
).sort_values(ascending=False)
# Out:
# Cabin          0.771044
# Age            0.198653
# Embarked       0.002245
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# dtype: float64

# %%
#izlediğiniz için teşekkürler
